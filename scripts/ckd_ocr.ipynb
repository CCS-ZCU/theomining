# %%
#!pip install PyMuPDF
import fitz
import requests
import io
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import pytesseract
#import cv2
import matplotlib.patches as patches
import re
from bs4 import BeautifulSoup
import pandas as pd
import nltk

# %%
import regex
import PyGoogleBooks

# %%
url = "http://depositum.cz/knihovny/ckd/strom.clanek.php?clanek=6659"
resp = requests.get(url)
soup = BeautifulSoup(resp.text)

# %%
resp = requests.get("http://depositum.cz/knihovny/ckd/index.php")
soup = BeautifulSoup(resp.text)
print(soup.prettify())
# Out:
# <!DOCTYPE Html PUBLIC "-//W3C//DTD Html 4.01//EN"
#         "http://www.w3.org/TR/Html4/strict.dtd">
# <html>
#  <meta content="text/Html; charset=utf-8" http-equiv="Content-Type"/>
#  <head>
#   <script src="/lib/widget/script/widget.js.php" type="text/javascript">
#   </script>
#   <link href="/knihovny/ckd/style/textgame.css" rel="stylesheet" type="text/css"/>
#   <link href="style/knihovna.css" rel="stylesheet" type="text/css"/>
#   <link href="style/index.css" rel="stylesheet" type="text/css"/>
#   <link href="style/menu.css" rel="stylesheet" type="text/css"/>
#   <title>
#    Knihovna
#   </title>
#  </head>
#  <body id="index">
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-49883798-5', 'depositum.cz');
#   ga('send', 'pageview');
#   </script>
#   <div class="txgame_page">
#    <div class="txgame_top">
#     <img id="gametop_img" src="img/depositum.gif"/>
#    </div>
#    <div class="txgame_side">
#     <h4 class="txgame_caption">
#      Prohlíej dle...
#     </h4>
#     <ul class="txgame_def">
#      <li class="txgame_def">
#       <a class="gamemenu" href="index.php?dle=">
#        Dle titulù
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gamemenu" href="index.php?dle=autor">
#        Dle autorù
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gamemenu" href="index.php?dle=keyword">
#        Dle klíèových slov
#       </a>
#      </li>
#     </ul>
#     <h4 class="txgame_caption">
#      Jdi na...
#     </h4>
#     <ul class="txgame_def">
#      <li class="txgame_def">
#       <a class="gamemenu" href="../..">
#        Hlavní stranu
#        <emph>
#         Deposita
#        </emph>
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gamemenu" href="help/simple.html">
#        Nápovìdu
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gamemenu" href="?knihovna:viewmode=1">
#        Rozíøené ovládací rozhraní
#       </a>
#      </li>
#     </ul>
#     <h4 class="txgame_caption">
#      Vyhledávání
#     </h4>
#     <ul class="txgame_def">
#      <li class="txgame_def">
#       <a class="gamemenu" href="index.php?dle=find">
#        Pokroèilé vyhledávání
#       </a>
#      </li>
#      <form action="?dle=find" method="post">
#       <input id="" name="nazev" type="text"/>
#       <input name="dle" type="hidden" value="find"/>
#       <input type="submit" value="Vyhledej!"/>
#      </form>
#     </ul>
#    </div>
#    <div class="txgame_body">
#     <h2 class="txgame_heading">
#      Prohlííte
#      <span class="txgame_emph">
#       èasopisy z této sekce
#       <emph>
#        Deposita
#       </emph>
#      </span>
#     </h2>
#     <h4 class="txgame_caption">
#      Zvol èasopis...
#     </h4>
#     <ul class="txgame_def">
#      <li class="txgame_def">
#       <a class="gameitem_casopis" href="/knihovny/ckd/index.php?txgame:typ=1&amp;txgame:id=1&amp;dle=rocnik">
#        ČKD
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#  </body>
# </html>

# %%
url = "http://depositum.cz/strany/ckd/original/232/844.jpg"
response = requests.get(url)

# Open the image file
img = Image.open(io.BytesIO(response.content))

# %% [markdown]
# Pro potřeby testování opět vybereme jednu náhodnou stránku a vytvoříme z ní objekt obrázku.

# %%
print(BeautifulSoup(resp.content).prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Knihovna
#   </title>
#   <link href="style/knihovna.css" rel="stylesheet" type="text/css"/>
#   <link href="style/index.css" rel="stylesheet" type="text/css"/>
#   <link href="style/menu.css" rel="stylesheet" type="text/css"/>
#   <script src="/lib/widget/script/widget.js.php" type="text/javascript">
#   </script>
#   <script src="/lib/widget/script/tree.js" type="text/javascript">
#   </script>
#   <script src="/lib/widget/script/splitter.js" type="text/javascript">
#   </script>
#   <script src="/lib/script/dom.js" type="text/javascript">
#   </script>
#   <script src="/lib/widget/script/list.js" type="text/javascript">
#   </script>
#   <script src="/lib/widget/script/sliderbar.js" type="text/javascript">
#   </script>
#   <script src="/knihovny/ckd/knihovna/script/knihovna.js" type="text/javascript">
#   </script>
#   <link href="/lib/widget/style/tree.css.php" rel="stylesheet" type="text/css"/>
#   <link href="/lib/widget/style/splitter.css.php" rel="stylesheet" type="text/css"/>
#   <link href="/lib/widget/style/list.css.php" rel="stylesheet" type="text/css"/>
#   <link href="/lib/widget/style/sliderbar.css.php" rel="stylesheet" type="text/css"/>
#   <script type="text/javascript">
#    <!--
# TWidget.sid = '1385447644';
# //-->
#   </script>
#  </head>
#  <body id="index">
#   <div id="menu">
#    <div id="menu_leve">
#     <a class="menuitem" href="index.php?dle=rocnik">
#      Ročníky
#     </a>
#     <a class="menuitem" href="index.php?dle=autor">
#      Autoři
#     </a>
#     <a class="menuitem" href="index.php?dle=keyword">
#      Klíčová slova
#     </a>
#    </div>
#    <div id="menu_prave">
#     <form action="find.php" method="post">
#      <a class="menuitem" href="help/simple.html">
#       Nápověda
#      </a>
#      <a class="menuitem" href="index.php?knihovna:viewmode=0">
#       Jednoduché
#      </a>
#      <input class="text" name="nazev" type="Text"/>
#      <input name="simple" type="hidden"/>
#      <input class="button" type="submit" value="Vyhledej"/>
#     </form>
#    </div>
#    <div id="menu_center">
#     <div id="widget_actionActive">
#     </div>
#     <div id="widget_actionDone">
#      <a href="/">
#       digiknihovna DEPOSITUM
#      </a>
#     </div>
#    </div>
#   </div>
#   //strom
#   <div class="TTreeView" id="strom">
#    <div class="tree_item" id="strom:1_1">
#     <span style="display:none">
#      `
#     </span>
#     <a class="tree_f_rozvin_last" id="strom:1_1:a" name="strom:1_1:a" onclick="return tree_folderClick('strom','1_1')">
#      <span style="display: none">
#       *&amp;nbsp
#      </span>
#     </a>
#     <a class="treeitem_casopis" id="strom:1_1:icon" onclick="return tree_select('strom','1_1');" ondblclick="return tree_expand('strom','1_1')">
#      ČKD
#     </a>
#    </div>
#    <div class="tree_items" id="strom:1_1:items">
#     <div class="tree_item" id="strom:r_1_182">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_182:a" name="strom:r_1_182:a" onclick="return tree_folderClick('strom','r_1_182');">
#       <span style="display: none">
#        +&amp;nbsp
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_182:icon" onclick="return tree_select('strom','r_1_182');" ondblclick="tree_expand('strom','r_1_182');">
#       1820 - 1829
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_182:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_183">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_183:a" name="strom:r_1_183:a" onclick="return tree_folderClick('strom','r_1_183');">
#       <span style="display: none">
#        +&amp;nbsp
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_183:icon" onclick="return tree_select('strom','r_1_183');" ondblclick="tree_expand('strom','r_1_183');">
#       1830 - 1839
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_183:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_184">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_184:a" name="strom:r_1_184:a" onclick="return tree_folderClick('strom','r_1_184');">
#       <span style="display: none">
#        +&amp;nbsp
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_184:icon" onclick="return tree_select('strom','r_1_184');" ondblclick="tree_expand('strom','r_1_184');">
#       1840 - 1849
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_184:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_185">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_185:a" name="strom:r_1_185:a" onclick="return tree_folderClick('strom','r_1_185');">
#       <span style="display: none">
#        +&amp;nbsp
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_185:icon" onclick="return tree_select('strom','r_1_185');" ondblclick="tree_expand('strom','r_1_185');">
#       1850 - 1859
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_185:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_186">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_186:a" name="strom:r_1_186:a" onclick="return tree_folderClick('strom','r_1_186');">
#       <span style="display: none">
#        +&amp;nbsp
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_186:icon" onclick="return tree_select('strom','r_1_186');" ondblclick="tree_expand('strom','r_1_186');">
#       1860 - 1869
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_186:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_187">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_rozvin" id="strom:r_1_187:a" name="strom:r_1_187:a" onclick="return tree_folderClick('strom','r_1_187')">
#       <span style="display: none">
#        *&amp;nbsp
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_187:icon" onclick="return tree_select('strom','r_1_187');" ondblclick="return tree_expand('strom','r_1_187')">
#       1870 - 1879
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_187:items">
#      <div class="tree_item" id="strom:2_339">
#       <span style="display:none">
#        |  |
#       </span>
#       <span class="tree_vetev_ne">
#       </span>
#       <span class="tree_vetev_je">
#       </span>
#       <a class="tree_f_svin" id="strom:2_339:a" name="strom:2_339:a" onclick="return tree_folderClick('strom','2_339');">
#        <span style="display: none">
#         +&amp;nbsp
#        </span>
#       </a>
#       <a class="treeitem_rocnik" id="strom:2_339:icon" onclick="return tree_select('strom','2_339');" ondblclick="tree_expand('strom','2_339');">
#        1870
#       </a>
#      </div>
#      <div class="tree_items" id="strom:2_339:items" style="display:none">
#      </div>
#      <div class="tree_item" id="strom:2_341">
#       <span style="display:none">
#        |  |
#       </span>
#       <span class="tree_vetev_ne">
#       </span>
#       <span class="tree_vetev_je">
#       </span>
#       <a class="tree_f_svin" id="strom:2_341:a" name="strom:2_341:a" onclick="return tree_folderClick('strom','2_341');">
#        <span style="display: none">
#         +&amp;nbsp
#        </span>
#       </a>
#       <a class="treeitem_rocnik" id="strom:2_341:icon" onclick="return tree_select('strom','2_341');" ondblclick="tree_expand('strom','2_341');">
#        1871
#       </a>
#      </div>
#      <div class="tree_items" id="strom:2_341:items" style="display:none">
#      </div>
#      <div class="tree_item" id="strom:2_342">
#       <span style="display:none">
#        |  |
#       </span>
#       <span class="tree_vetev_ne">
#       </span>
#       <span class="tree_vetev_je">
#       </span>
#       <a class="tree_f_svin" id="strom:2_342:a" name="strom:2_342:a" onclick="return tree_folderClick('strom','2_342');">
#        <span style="display: none">
#         +&amp;nbsp
#        </span>
#       </a>
#       <a class="treeitem_rocnik" id="strom:2_342:icon" onclick="return tree_select('strom','2_342');" ondblclick="tree_expand('strom','2_342');">
#        1872
#       </a>
#      </div>
#      <div class="tree_items" id="strom:2_342:items" style="display:none">
#      </div>
#      <div class="tree_item" id="strom:2_343">
#       <span style="display:none">
#        |  |
#       </span>
#       <span class="tree_vetev_ne">
#       </span>
#       <span class="tree_vetev_je">
#       </span>
#       <a class="tree_f_rozvin" id="strom:2_343:a" name="strom:2_343:a" onclick="return tree_folderClick('strom','2_343')">
#        <span style="display: none">
#         *&amp;nbsp
#        </span>
#       </a>
#       <a class="treeitem_rocnik" id="strom:2_343:icon" onclick="return tree_select('strom','2_343');" ondblclick="return tree_expand('strom','2_343')">
#        1873
#       </a>
#      </div>
#      <div class="tree_items" id="strom:2_343:items">
#       <div class="tree_item" id="strom:3_404">
#        <span style="display:none">
#         |  |  |
#        </span>
#        <span class="tree_vetev_ne">
#        </span>
#        <span class="tree_vetev_je">
#        </span>
#        <span class="tree_vetev_je">
#        </span>
#        <a class="tree_f_svin" id="strom:3_404:a" name="strom:3_404:a" onclick="return tree_folderClick('strom','3_404');">
#         <span style="display: none">
#          +&amp;nbsp
#         </span>
#        </a>
#        <a class="treeitem_cislo" id="strom:3_404:icon" onclick="return tree_select('strom','3_404');" ondblclick="tree_expand('strom','3_404');">
#         1
#        </a>
#       </div>
#       <div class="tree_items" id="strom:3_404:items" style="display:none">
#       </div>
#       <div class="tree_item" id="strom:3_405">
#        <span style="display:none">
#         |  |  |
#        </span>
#        <span class="tree_vetev_ne">
#        </span>
#        <span class="tree_vetev_je">
#        </span>
#        <span class="tree_vetev_je">
#        </span>
#        <a class="tree_f_svin" id="strom:3_405:a" name="strom:3_405:a" onclick="return tree_folderClick('strom','3_405');">
#         <span style="display: none">
#          +&amp;nbsp
#         </span>
#        </a>
#        <a class="treeitem_cislo" id="strom:3_405:icon" onclick="return tree_select('strom','3_405');" ondblclick="tree_expand('strom','3_405');">
#         2
#        </a>
#       </div>
#       <div class="tree_items" id="strom:3_405:items" style="display:none">
#       </div>
#       <div class="tree_item" id="strom:3_406">
#        <span style="display:none">
#         |  |  |
#        </span>
#        <span class="tree_vetev_ne">
#        </span>
#        <span class="tree_vetev_je">
#        </span>
#        <span class="tree_vetev_je">
#        </span>
#        <a class="tree_f_svin" id="strom:3_406:a" name="strom:3_406:a" onclick="return tree_folderClick('strom','3_406');">
#         <span style="display: none">
#          +&amp;nbsp
#         </span>
#        </a>
#        <a class="treeitem_cislo" id="strom:3_406:icon" onclick="return tree_select('strom','3_406');" ondblclick="tree_expand('strom','3_406');">
#         3
#        </a>
#       </div>
#       <div class="tree_items" id="strom:3_406:items" style="display:none">
#       </div>
#       <div class="tree_item" id="strom:3_407">
#        <span style="display:none">
#         |  |  |
#        </span>
#        <span class="tree_vetev_ne">
#        </span>
#        <span class="tree_vetev_je">
#        </span>
#        <span class="tree_vetev_je">
#        </span>
#        <a class="tree_f_svin" id="strom:3_407:a" name="strom:3_407:a" onclick="return tree_folderClick('strom','3_407');">
#         <span style="display: none">
#          +&amp;nbsp
#         </span>
#        </a>
#        <a class="treeitem_cislo" id="strom:3_407:icon" onclick="return tree_select('strom','3_407');" ondblclick="tree_expand('strom','3_407');">
#         4
#        </a>
#       </div>
#       <div class="tree_items" id="strom:3_407:items" style="display:none">
#       </div>
#       <div class="tree_item" id="strom:3_408">
#        <span style="display:none">
#         |  |  |
#        </span>
#        <span class="tree_vetev_ne">
#        </span>
#        <span class="tree_vetev_je">
#        </span>
#        <span class="tree_vetev_je">
#        </span>
#        <a class="tree_f_svin" id="strom:3_408:a" name="strom:3_408:a" onclick="return tree_folderClick('strom','3_408');">
#         <span style="display: none">
#          +&amp;nbsp
#         </span>
#        </a>
#        <a class="treeitem_cislo" id="strom:3_408:icon" onclick="return tree_select('strom','3_408');" ondblclick="tree_expand('strom','3_408');">
#         5
#        </a>
#       </div>
#       <div class="tree_items" id="strom:3_408:items" style="display:none">
#       </div>
#       <div class="tree_item" id="strom:3_409">
#        <span style="display:none">
#         |  |  `
#        </span>
#        <span class="tree_vetev_ne">
#        </span>
#        <span class="tree_vetev_je">
#        </span>
#        <span class="tree_vetev_je">
#        </span>
#        <a class="tree_f_rozvin_last" id="strom:3_409:a" name="strom:3_409:a" onclick="return tree_folderClick('strom','3_409')">
#         <span style="display: none">
#          *&amp;nbsp
#         </span>
#        </a>
#        <a class="treeitem_cislo" id="strom:3_409:icon" onclick="return tree_select('strom','3_409');" ondblclick="return tree_expand('strom','3_409')">
#         6
#        </a>
#       </div>
#       <div class="tree_items" id="strom:3_409:items">
#        <div class="tree_item" id="strom:c_6648">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6648:a" name="strom:c_6648:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6648:icon" onclick="return tree_select('strom','c_6648');">
#          Řeč obranná o kněžství.
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6649">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6649:a" name="strom:c_6649:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6649:icon" onclick="return tree_select('strom','c_6649');">
#          Koadjutor churavého biskupa.
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6651">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6651:a" name="strom:c_6651:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6651:icon" onclick="return tree_select('strom','c_6651');">
#          Msta v žalmech.
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6653">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6653:a" name="strom:c_6653:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6653:icon" onclick="return tree_select('strom','c_6653');">
#          Palác biskupský v Praze.
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6654">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6654:a" name="strom:c_6654:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6654:icon" onclick="return tree_select('strom','c_6654');">
#          O legendách.
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6657">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6657:a" name="strom:c_6657:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6657:icon" onclick="return tree_select('strom','c_6657');">
#          Z pastorální konference vikariátu Dešenického, konané v září 1873.
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6659">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6659:a" name="strom:c_6659:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek_selected" id="strom:c_6659:icon" onclick="return tree_select('strom','c_6659');">
#          Benedikce korporalií ke mši sv.
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6660">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6660:a" name="strom:c_6660:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6660:icon" onclick="return tree_select('strom','c_6660');">
#          Adopce nebo schovanství.
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6662">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6662:a" name="strom:c_6662:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6662:icon" onclick="return tree_select('strom','c_6662');">
#          Seznam údů a účastníků Dědictví sv. Prokopa.
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6663">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6663:a" name="strom:c_6663:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6663:icon" onclick="return tree_select('strom','c_6663');">
#          Literární listy.
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6664">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6664:a" name="strom:c_6664:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6664:icon" onclick="return tree_select('strom','c_6664');">
#          Katechismus...
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6665">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6665:a" name="strom:c_6665:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6665:icon" onclick="return tree_select('strom','c_6665');">
#          Kritická úvaha o pojednání Alfonsa Šťastného " Ježíš a jeho poměr ku křesťanství,"... V. Brandl
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6666">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6666:a" name="strom:c_6666:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6666:icon" onclick="return tree_select('strom','c_6666');">
#          Čtyři doby v historii české... Dr. Klement Borový
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6667">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6667:a" name="strom:c_6667:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6667:icon" onclick="return tree_select('strom','c_6667');">
#          Učitelský kalendář na rok 1874... Josef Balcar
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6668">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6668:a" name="strom:c_6668:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6668:icon" onclick="return tree_select('strom','c_6668');">
#          Zlaté klasy.... prof. Jan Suda
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6669">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6669:a" name="strom:c_6669:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6669:icon" onclick="return tree_select('strom','c_6669');">
#          Zlaté lístky... K. A. Madiera
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6670">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6670:a" name="strom:c_6670:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6670:icon" onclick="return tree_select('strom','c_6670');">
#          Cizinci o štědrém večeru... Jos. Baar
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6671">
#         <span style="display:none">
#          |  |     |
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list" id="strom:c_6671:a" name="strom:c_6671:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6671:icon" onclick="return tree_select('strom','c_6671');">
#          Obsah
#         </a>
#        </div>
#        <div class="tree_item" id="strom:c_6672">
#         <span style="display:none">
#          |  |     `
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_je">
#         </span>
#         <span class="tree_vetev_ne">
#         </span>
#         <a class="tree_f_list_last" id="strom:c_6672:a" name="strom:c_6672:a">
#          <span style="display: none">
#           -&amp;nbsp
#          </span>
#         </a>
#         <a class="treeitem_clanek" id="strom:c_6672:icon" onclick="return tree_select('strom','c_6672');">
#          Nákladem kněhoskladu Rohlíčka a Sieverse... vyšly... knihy:
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="tree_item" id="strom:2_344">
#       <span style="display:none">
#        |  |
#       </span>
#       <span class="tree_vetev_ne">
#       </span>
#       <span class="tree_vetev_je">
#       </span>
#       <a class="tree_f_svin" id="strom:2_344:a" name="strom:2_344:a" onclick="return tree_folderClick('strom','2_344');">
#        <span style="display: none">
#         +&amp;nbsp
#        </span>
#       </a>
#       <a class="treeitem_rocnik" id="strom:2_344:icon" onclick="return tree_select('strom','2_344');" ondblclick="tree_expand('strom','2_344');">
#        1874
#       </a>
#      </div>
#      <div class="tree_items" id="strom:2_344:items" style="display:none">
#      </div>
#      <div class="tree_item" id="strom:2_345">
#       <span style="display:none">
#        |  |
#       </span>
#       <span class="tree_vetev_ne">
#       </span>
#       <span class="tree_vetev_je">
#       </span>
#       <a class="tree_f_svin" id="strom:2_345:a" name="strom:2_345:a" onclick="return tree_folderClick('strom','2_345');">
#        <span style="display: none">
#         +&amp;nbsp
#        </span>
#       </a>
#       <a class="treeitem_rocnik" id="strom:2_345:icon" onclick="return tree_select('strom','2_345');" ondblclick="tree_expand('strom','2_345');">
#        1875
#       </a>
#      </div>
#      <div class="tree_items" id="strom:2_345:items" style="display:none">
#      </div>
#      <div class="tree_item" id="strom:2_346">
#       <span style="display:none">
#        |  |
#       </span>
#       <span class="tree_vetev_ne">
#       </span>
#       <span class="tree_vetev_je">
#       </span>
#       <a class="tree_f_svin" id="strom:2_346:a" name="strom:2_346:a" onclick="return tree_folderClick('strom','2_346');">
#        <span style="display: none">
#         +&amp;nbsp
#        </span>
#       </a>
#       <a class="treeitem_rocnik" id="strom:2_346:icon" onclick="return tree_select('strom','2_346');" ondblclick="tree_expand('strom','2_346');">
#        1876
#       </a>
#      </div>
#      <div class="tree_items" id="strom:2_346:items" style="display:none">
#      </div>
#      <div class="tree_item" id="strom:2_347">
#       <span style="display:none">
#        |  |
#       </span>
#       <span class="tree_vetev_ne">
#       </span>
#       <span class="tree_vetev_je">
#       </span>
#       <a class="tree_f_svin" id="strom:2_347:a" name="strom:2_347:a" onclick="return tree_folderClick('strom','2_347');">
#        <span style="display: none">
#         +&amp;nbsp
#        </span>
#       </a>
#       <a class="treeitem_rocnik" id="strom:2_347:icon" onclick="return tree_select('strom','2_347');" ondblclick="tree_expand('strom','2_347');">
#        1877
#       </a>
#      </div>
#      <div class="tree_items" id="strom:2_347:items" style="display:none">
#      </div>
#      <div class="tree_item" id="strom:2_348">
#       <span style="display:none">
#        |  |
#       </span>
#       <span class="tree_vetev_ne">
#       </span>
#       <span class="tree_vetev_je">
#       </span>
#       <a class="tree_f_svin" id="strom:2_348:a" name="strom:2_348:a" onclick="return tree_folderClick('strom','2_348');">
#        <span style="display: none">
#         +&amp;nbsp
#        </span>
#       </a>
#       <a class="treeitem_rocnik" id="strom:2_348:icon" onclick="return tree_select('strom','2_348');" ondblclick="tree_expand('strom','2_348');">
#        1878
#       </a>
#      </div>
#      <div class="tree_items" id="strom:2_348:items" style="display:none">
#      </div>
#      <div class="tree_item" id="strom:2_349">
#       <span style="display:none">
#        |  `
#       </span>
#       <span class="tree_vetev_ne">
#       </span>
#       <span class="tree_vetev_je">
#       </span>
#       <a class="tree_f_svin_last" id="strom:2_349:a" name="strom:2_349:a" onclick="return tree_folderClick('strom','2_349');">
#        <span style="display: none">
#         +&amp;nbsp
#        </span>
#       </a>
#       <a class="treeitem_rocnik" id="strom:2_349:icon" onclick="return tree_select('strom','2_349');" ondblclick="tree_expand('strom','2_349');">
#        1879
#       </a>
#      </div>
#      <div class="tree_items" id="strom:2_349:items" style="display:none">
#      </div>
#     </div>
#     <div class="tree_item" id="strom:r_1_188">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_188:a" name="strom:r_1_188:a" onclick="return tree_folderClick('strom','r_1_188');">
#       <span style="display: none">
#        +&amp;nbsp
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_188:icon" onclick="return tree_select('strom','r_1_188');" ondblclick="tree_expand('strom','r_1_188');">
#       1880 - 1889
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_188:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_189">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_189:a" name="strom:r_1_189:a" onclick="return tree_folderClick('strom','r_1_189');">
#       <span style="display: none">
#        +&amp;nbsp
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_189:icon" onclick="return tree_select('strom','r_1_189');" ondblclick="tree_expand('strom','r_1_189');">
#       1890 - 1899
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_189:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_190">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_190:a" name="strom:r_1_190:a" onclick="return tree_folderClick('strom','r_1_190');">
#       <span style="display: none">
#        +&amp;nbsp
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_190:icon" onclick="return tree_select('strom','r_1_190');" ondblclick="tree_expand('strom','r_1_190');">
#       1900 - 1909
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_190:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_191">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_191:a" name="strom:r_1_191:a" onclick="return tree_folderClick('strom','r_1_191');">
#       <span style="display: none">
#        +&amp;nbsp
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_191:icon" onclick="return tree_select('strom','r_1_191');" ondblclick="tree_expand('strom','r_1_191');">
#       1910 - 1919
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_191:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_192">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_192:a" name="strom:r_1_192:a" onclick="return tree_folderClick('strom','r_1_192');">
#       <span style="display: none">
#        +&amp;nbsp
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_192:icon" onclick="return tree_select('strom','r_1_192');" ondblclick="tree_expand('strom','r_1_192');">
#       1920 - 1929
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_192:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_193">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_193:a" name="strom:r_1_193:a" onclick="return tree_folderClick('strom','r_1_193');">
#       <span style="display: none">
#        +&amp;nbsp
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_193:icon" onclick="return tree_select('strom','r_1_193');" ondblclick="tree_expand('strom','r_1_193');">
#       1930 - 1939
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_193:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_194">
#      <span style="display:none">
#       `
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin_last" id="strom:r_1_194:a" name="strom:r_1_194:a" onclick="return tree_folderClick('strom','r_1_194');">
#       <span style="display: none">
#        +&amp;nbsp
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_194:icon" onclick="return tree_select('strom','r_1_194');" ondblclick="tree_expand('strom','r_1_194');">
#       1940 - 1949
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_194:items" style="display:none">
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    var ja=new TWidget.okno.TProxy(TWidget.proxies,'strom','TTreeView');
# 	ja.css_prefix = '';
# 	TWidget.cache.init('strom');
# 	ja.slaves=new Object();
# 	ja.members=new Object();
# 	ja.linked=new Object();
# 	ja.handlers.select= TWidget.okno.tree_select;
# 	ja.handlers.select_child= TWidget.okno.tree_select_child;
# 	ja.handlers.update= TWidget.okno.widget_masterUpdate;
# 	ja.handlers.getSelectedText= TWidget.okno.tree_getSelectedText;
# 	ja.handlers.cache= TWidget.okno.widget_cache;
# 	ja.handlers.restore= TWidget.okno.widget_restore;
# 	ja.store.key="c_6659";
#   </script>
#   //splitter
#   <div class="TSplitterVertical" id="splitter" onmousedown="return widget_splitter_down(this,event); ">
#   </div>
#   <script type="text/javascript">
#    var ja=new TWidget.okno.TProxy(TWidget.proxies,'splitter','TSplitter');
# 	ja.css_prefix = '';
# 	 ja.vertical=true;
# widget_splitter_init(ja);	 ja.levy['strom']='strom';
# 	 ja.pravy['panel']='panel';
# 	 ja.left_min=30;
# 	 ja.right_min=30;
# 	ja.handlers.restore= TWidget.okno.widget_splitter_restore;
#   </script>
#   //panel
#   <div class="TKnihyPanel" id="panel">
#    //panel_clanek
#    <div class="TClanekPanel" id="panel_clanek">
#     <div class="nadpis_clanku">
#      Benedikce korporalií ke mši sv.
#     </div>
#     <div class="TClanekPanel_Icons" id="panel_clanek_icons">
#      <div>
#       <img alt="Zvětši" class="clanek_icon" id="panel_clanek_button_zoomplus" onclick="textpanel_zoom('panel_clanek_text',1)" src="img/lupaplus.gif" title="Zvětši zobrazenou stranu"/>
#       <img alt="Zmenši" class="clanek_icon" id="panel_clanek_button_zoomminus" onclick="textpanel_zoom('panel_clanek_text',-1)" src="img/lupaminus.gif" title="Zmenší zobrazenou stranu"/>
#       <img class="clanek_icon" id="panel_clanek_button_previouspage" onclick="clanek_goNextOrToClanek('panel_clanek',-1,'previouspage')" src="img/pageprev.gif" title="Předchozí strana"/>
#       <img class="clanek_icon" id="panel_clanek_button_nextpage" onclick="clanek_goNextOrToClanek('panel_clanek',1,'nextpage')" src="img/pagenext.gif" title="Další strana"/>
#      </div>
#      <div>
#       <a class="clanek_icon" href="clanek.php?id=c_6659&amp;session:new=1" target="_blank">
#        <img src="img/clanek.gif" title="Zobraz článek v samostatném okně"/>
#       </a>
#       <a class="clanek_icon" href="tiskclanek.php?id=c_6659&amp;session:new=1" target="_blank">
#        <img src="img/clanekprint.gif" title="Zobraz článek pro tisk"/>
#       </a>
#       <img alt="Zvětši" class="clanek_icon" id="panel_clanek_button_nextpagex" onclick="clanek_showInfo('panel_clanek',1)" src="img/info.gif" title="Zvětši zobrazenou stranu"/>
#      </div>
#     </div>
#     //panel_clanek_bar
# //panel_clanek_pages
#     <div class="TSliderBar" id="panel_clanek_bar">
#      <div class="knihovna_bar_leve" id="panel_clanek_bar_leve">
#       <div class="knihovna_bar_prepinac" id="panel_clanek_bar_prepinac">
#       </div>
#      </div>
#      <div class="knihovna_bar_prave" id="panel_clanek_bar_prave">
#       <a class="slider_minuly" id="panel_clanek_bar_minuly" onclick="return slider_jump('panel_clanek_bar',-1);">
#        <span>
#         <span>
#          &lt;
#         </span>
#        </span>
#       </a>
#       <a class="slider_item_selected" id="panel_clanek_bar_1" onclick="return slider_jumpTo('panel_clanek_bar',1);">
#        <span>
#         1
#        </span>
#       </a>
#       <a class="slider_item" id="panel_clanek_bar_2" onclick="return slider_jumpTo('panel_clanek_bar',2);">
#        <span>
#         2
#        </span>
#       </a>
#       <a class="slider_item" id="panel_clanek_bar_3" onclick="return slider_jumpTo('panel_clanek_bar',3);">
#        <span>
#         3
#        </span>
#       </a>
#       <a class="slider_dalsi" id="panel_clanek_bar_dalsi" onclick="return slider_jump('panel_clanek_bar',1);">
#        <span>
#         &gt;
#        </span>
#       </a>
#      </div>
#     </div>
#     //panel_clanek_text
#     <div class="TTextPanel" id="panel_clanek_text">
#      <div class=".TTextPanel_container" id="panel_clanek_text_container">
#       <img alt="Stránka 216296" id="panel_clanek_text_img" onabort="textpanel_onendimg('panel_clanek_text')" onerror="textpanel_onendimg('panel_clanek_text')" onload="textpanel_onloadimg('panel_clanek_text')" onunload="textpanel_onendimg('panel_clanek_text')" src="/strany/ckd/original/232/844.jpg"/>
#      </div>
#     </div>
#     <div class="TPagesBar" id="panel_clanek_pages">
#      <a class="slider_item_selected" id="panel_clanek_pages_1" onclick="return slider_jumpTo('panel_clanek_pages',1);">
#       <img src="/strany/ckd/thumbnail/232/844.jpg"/>
#      </a>
#      <a class="slider_item" id="panel_clanek_pages_2" onclick="return slider_jumpTo('panel_clanek_pages',2);">
#       <img src="/strany/ckd/thumbnail/233/844.jpg"/>
#      </a>
#      <a class="slider_item" id="panel_clanek_pages_3" onclick="return slider_jumpTo('panel_clanek_pages',3);">
#       <img src="/strany/ckd/thumbnail/234/844.jpg"/>
#      </a>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    var ja=new TWidget.okno.TProxy(TWidget.proxies,'panel','TKnihyPanel');
# 	ja.css_prefix = '';
# 	ja.setMaster(TWidget.proxies.get('strom'));
# 	TWidget.proxies.get('strom').addSlaveProxy(ja);
# 	TWidget.cache.init('panel');
# 	ja.slaves=new Object();
# 	ja.members=new Object();
# 	ja.handlers.select= TWidget.okno.widget_select;
# 	ja.handlers.update= TWidget.okno.widget_panelUpdate;
# 	ja.handlers.translateKey= TWidget.okno.knihyPanel_translateKey;
# 	ja.handlers.cache= TWidget.okno.widget_cache;
# 	ja.handlers.restore= TWidget.okno.widget_restore;
# 	ja.store.masterKey = 'c_6659';
# 	ja.store.key="c_6659";
# var ja=new TWidget.okno.TProxy(TWidget.proxies,'panel_clanek','TClanekPanel');
# 	ja.css_prefix = '';
# 	ja.setMaster(TWidget.proxies.get('panel'));
# 	TWidget.proxies.get('panel').addSlaveProxy(ja);
# 	TWidget.cache.init('panel_clanek');
# 	ja.slaves=new Object();
# 	ja.members=new Object();
# var ja=TWidget.proxies.get("panel_clanek");
# ja.store["previouspage"]=6657;
# ja.store["nextpage"]=6660;
# clanek_setButtonDisable('panel_clanek',6657,'previouspage');
# clanek_setButtonDisable('panel_clanek',6660,'nextpage');
# ja.store['previous']=0;
# ja.store['next']=0;
# 	ja.handlers.select= TWidget.okno.widget_select;
# 	ja.handlers.update= TWidget.okno.widget_update;
# 	ja.handlers.cache= TWidget.okno.widget_cache;
# 	ja.handlers.restore= TWidget.okno.widget_restore;
# 	ja.store.masterKey = 'c_6659';
# 	ja.store.key="c_6659";
# var ja=new TWidget.okno.TProxy(TWidget.proxies,'panel_clanek_bar','TKnihovnaSliderbarIndex');
# 	ja.css_prefix = '';
# 	ja.setMaster(TWidget.proxies.get('panel_clanek'));
# 	TWidget.proxies.get('panel_clanek').addSlaveProxy(ja);
# 	TWidget.cache.init('panel_clanek_bar');
# 	ja.slaves=new Object();
# 	ja.members=new Object();
# 	ja.linked=new Object();
# 	ja.linked['panel_clanek_pages']=function(){var ja=new TWidget.okno.TProxy(TWidget.proxies,'panel_clanek_pages','TClanekPagebar');
# 	ja.css_prefix = '';
# 	ja.setMaster(TWidget.proxies.get('panel_clanek'));
# 	TWidget.proxies.get('panel_clanek').addSlaveProxy(ja);
# 	TWidget.cache.init('panel_clanek_pages');
# 	ja.slaves=new Object();
# 	ja.members=new Object();
# 	ja.linked=new Object();
# 	ja.linkedMaster=TWidget.proxies.get('panel_clanek_bar');
# ; return ja; }();
# ja.prefetch=TWidget.okno.knihovnaSliderbar_prefetchImg;
# 	ja.store.keys = Array();
# ja.store.keys[1] = '1_267867_216296';
# ja.store.keys[2] = '2_267868_216297';
# ja.store.keys[3] = '3_267869_216298';
# 	ja.handlers.update= TWidget.okno.widget_masterUpdate;
# 	ja.handlers.selected= TWidget.okno.knihovnaSliderbar_prefetch;
# 	ja.handlers.select= TWidget.okno.slider_select;
# 	ja.handlers.jump= TWidget.okno.slider_jump;
# 	ja.handlers.jumpTo= TWidget.okno.slider_jumpTo;
# 	ja.handlers.overflow= TWidget.okno.clanekPages_jumpOut;
# 	ja.handlers.cache= TWidget.okno.widget_cache;
# 	ja.handlers.restore= TWidget.okno.widget_restore;
# 	ja.store.masterKey = 'c_6659';
# 	ja.store.key="1_267867_216296";
# ja.store.maximum = 3;
# ja.store.cislo = 1;
# ja.showMaxVOkoli = 4;
# ja.showHiddenBy = 10;
# knihovnaSliderbar_prefetch('panel_clanek_bar');
# slider_hideItems(ja);
# widget_scrollInViewHorById('panel_clanek_bar_1','panel_clanek_bar');
# var ja=new TWidget.okno.TProxy(TWidget.proxies,'panel_clanek_text','TTextPanel');
# 	ja.css_prefix = '';
# 	ja.setMaster(TWidget.proxies.get('panel_clanek_bar'));
# 	TWidget.proxies.get('panel_clanek_bar').addSlaveProxy(ja);
# 	TWidget.cache.init('panel_clanek_text');
# ja.original = 1;
# ja.zoom=1;
# 	ja.handlers.update= TWidget.okno.textpanel_update;
# 	ja.handlers.restore= TWidget.okno.textpanel_restore;
# 	ja.store.masterKey = '1_267867_216296';
# var ja=TWidget.proxies.get('panel_clanek_pages');
# 	ja.store.keys = Array();
# ja.store.keys[1] = '1_267867_216296';
# ja.store.keys[2] = '2_267868_216297';
# ja.store.keys[3] = '3_267869_216298';
# 	ja.handlers.update= TWidget.okno.widget_masterUpdate;
# 	ja.handlers.selected= TWidget.okno.clanekPages_showButtonsPrevNextPage;
# 	ja.handlers.select= TWidget.okno.slider_select;
# 	ja.handlers.jump= TWidget.okno.slider_jump;
# 	ja.handlers.jumpTo= TWidget.okno.slider_jumpTo;
# 	ja.handlers.overflow= TWidget.okno.slider_overflow;
# 	ja.handlers.cache= TWidget.okno.widget_cache;
# 	ja.handlers.restore= TWidget.okno.widget_restore;
# 	ja.store.masterKey = 'c_6659';
# 	ja.store.key="1_267867_216296";
# ja.store.maximum = 3;
# ja.store.cislo = 1;
# ja.showMaxVOkoli = 0;
# ja.showHiddenBy = 1;
# clanekPages_showButtonsPrevNextPage('panel_clanek_pages');
# widget_scrollInViewHorById('panel_clanek_pages_1','panel_clanek_pages');
# var ja=TWidget.proxies.get('panel');
#  TWidget.cache.cache(ja,ja.callAction('translateKey','c_6659'));
# TWidget.cache.cache(TWidget.proxies.get('panel_clanek'),'c_6659');
# TWidget.cache.cache(TWidget.proxies.get('panel_clanek_bar'),'c_6659');
# TWidget.cache.cache(TWidget.proxies.get('panel_clanek_text'),'*');
# textpanel_load('panel_clanek_text');
# TWidget.cache.cache(TWidget.proxies.get('panel_clanek_pages'),'c_6659');
#   </script>
#  </body>
# </html>

# %%
with open("../data/ckd_years.html") as fp:
    soup = BeautifulSoup(fp)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD Html 4.01//EN" "http://www.w3.org/TR/Html4/strict.dtd">
# <html>
#  <head>
#   <meta content="text/Html; charset=utf-8" http-equiv="Content-Type"/>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-7FB5E9QP3D&amp;cx=c&amp;_slc=1" type="text/javascript">
#   </script>
#   <script async="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script src="/lib/widget/script/widget.js.php" type="text/javascript">
#   </script>
#   <script src="/lib/widget/script/tree.js" type="text/javascript">
#   </script>
#   <script src="/lib/widget/script/splitter.js" type="text/javascript">
#   </script>
#   <script src="/lib/script/dom.js" type="text/javascript">
#   </script>
#   <script src="/lib/widget/script/list.js" type="text/javascript">
#   </script>
#   <script src="/lib/widget/script/sliderbar.js" type="text/javascript">
#   </script>
#   <script src="/knihovny/ckd/knihovna/script/knihovna.js" type="text/javascript">
#   </script>
#   <link href="/lib/widget/style/tree.css.php" rel="stylesheet" type="text/css"/>
#   <link href="/lib/widget/style/splitter.css.php" rel="stylesheet" type="text/css"/>
#   <link href="/lib/widget/style/list.css.php" rel="stylesheet" type="text/css"/>
#   <link href="/lib/widget/style/sliderbar.css.php" rel="stylesheet" type="text/css"/>
#   <script type="text/javascript">
#    TWidget.sid = '12002750';
#   </script>
#   <link href="style/knihovna.css" rel="stylesheet" type="text/css"/>
#   <link href="style/index.css" rel="stylesheet" type="text/css"/>
#   <link href="style/menu.css" rel="stylesheet" type="text/css"/>
#   <title>
#    Knihovna
#   </title>
#  </head>
#  <body id="index">
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-49883798-5', 'depositum.cz');
#   ga('send', 'pageview');
#   </script>
#   <div id="menu">
#    <div id="menu_leve">
#     <a class="menuitem_selected" href="index.php?dle=rocnik">
#      Ročníky
#     </a>
#     <a class="menuitem" href="index.php?dle=autor">
#      Autoři
#     </a>
#     <a class="menuitem" href="index.php?dle=keyword">
#      Klíčová slova
#     </a>
#    </div>
#    <div id="menu_prave">
#     <form action="find.php" method="post">
#      <a class="menuitem" href="help/simple.html">
#       Nápověda
#      </a>
#      <a class="menuitem" href="index.php?knihovna:viewmode=0">
#       Jednoduché
#      </a>
#      <input class="text" name="nazev" type="Text"/>
#      <input name="simple" type="hidden"/>
#      <input class="button" type="submit" value="Vyhledej"/>
#     </form>
#    </div>
#    <div id="menu_center">
#     <div id="widget_actionActive" style="display: none;">
#     </div>
#     <div id="widget_actionDone" style="display: block;">
#      <a href="/">
#       digiknihovna DEPOSITUM
#      </a>
#     </div>
#    </div>
#   </div>
#   //strom
#   <div class="TTreeView" id="strom" style="width: 223px;">
#    <div class="tree_item" id="strom:1_1">
#     <span style="display:none">
#      `
#     </span>
#     <a class="tree_f_rozvin_last" id="strom:1_1:a" name="strom:1_1:a" onclick="return tree_folderClick('strom','1_1')">
#      <span style="display: none">
#       *
#      </span>
#     </a>
#     <a class="treeitem_casopis_selected" id="strom:1_1:icon" onclick="return tree_select('strom','1_1');" ondblclick="return tree_expand('strom','1_1')">
#      ČKD
#     </a>
#    </div>
#    <div class="tree_items" id="strom:1_1:items" style="">
#     <div class="tree_item" id="strom:r_1_182">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_182:a" name="strom:r_1_182:a" onclick="return tree_folderClick('strom','r_1_182');">
#       <span style="display: none">
#        +
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_182:icon" onclick="return tree_select('strom','r_1_182');" ondblclick="tree_expand('strom','r_1_182');">
#       1820 - 1829
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_182:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_183">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_183:a" name="strom:r_1_183:a" onclick="return tree_folderClick('strom','r_1_183');">
#       <span style="display: none">
#        +
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_183:icon" onclick="return tree_select('strom','r_1_183');" ondblclick="tree_expand('strom','r_1_183');">
#       1830 - 1839
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_183:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_184">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_184:a" name="strom:r_1_184:a" onclick="return tree_folderClick('strom','r_1_184');">
#       <span style="display: none">
#        +
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_184:icon" onclick="return tree_select('strom','r_1_184');" ondblclick="tree_expand('strom','r_1_184');">
#       1840 - 1849
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_184:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_185">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_185:a" name="strom:r_1_185:a" onclick="return tree_folderClick('strom','r_1_185');">
#       <span style="display: none">
#        +
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_185:icon" onclick="return tree_select('strom','r_1_185');" ondblclick="tree_expand('strom','r_1_185');">
#       1850 - 1859
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_185:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_186">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_186:a" name="strom:r_1_186:a" onclick="return tree_folderClick('strom','r_1_186');">
#       <span style="display: none">
#        +
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_186:icon" onclick="return tree_select('strom','r_1_186');" ondblclick="tree_expand('strom','r_1_186');">
#       1860 - 1869
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_186:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_187">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_187:a" name="strom:r_1_187:a" onclick="return tree_folderClick('strom','r_1_187');">
#       <span style="display: none">
#        +
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_187:icon" onclick="return tree_select('strom','r_1_187');" ondblclick="tree_expand('strom','r_1_187');">
#       1870 - 1879
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_187:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_188">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_188:a" name="strom:r_1_188:a" onclick="return tree_folderClick('strom','r_1_188');">
#       <span style="display: none">
#        +
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_188:icon" onclick="return tree_select('strom','r_1_188');" ondblclick="tree_expand('strom','r_1_188');">
#       1880 - 1889
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_188:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_189">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_189:a" name="strom:r_1_189:a" onclick="return tree_folderClick('strom','r_1_189');">
#       <span style="display: none">
#        +
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_189:icon" onclick="return tree_select('strom','r_1_189');" ondblclick="tree_expand('strom','r_1_189');">
#       1890 - 1899
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_189:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_190">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_190:a" name="strom:r_1_190:a" onclick="return tree_folderClick('strom','r_1_190');">
#       <span style="display: none">
#        +
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_190:icon" onclick="return tree_select('strom','r_1_190');" ondblclick="tree_expand('strom','r_1_190');">
#       1900 - 1909
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_190:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_191">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_191:a" name="strom:r_1_191:a" onclick="return tree_folderClick('strom','r_1_191');">
#       <span style="display: none">
#        +
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_191:icon" onclick="return tree_select('strom','r_1_191');" ondblclick="tree_expand('strom','r_1_191');">
#       1910 - 1919
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_191:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_192">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_192:a" name="strom:r_1_192:a" onclick="return tree_folderClick('strom','r_1_192');">
#       <span style="display: none">
#        +
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_192:icon" onclick="return tree_select('strom','r_1_192');" ondblclick="tree_expand('strom','r_1_192');">
#       1920 - 1929
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_192:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_193">
#      <span style="display:none">
#       |
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin" id="strom:r_1_193:a" name="strom:r_1_193:a" onclick="return tree_folderClick('strom','r_1_193');">
#       <span style="display: none">
#        +
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_193:icon" onclick="return tree_select('strom','r_1_193');" ondblclick="tree_expand('strom','r_1_193');">
#       1930 - 1939
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_193:items" style="display:none">
#     </div>
#     <div class="tree_item" id="strom:r_1_194">
#      <span style="display:none">
#       `
#      </span>
#      <span class="tree_vetev_ne">
#      </span>
#      <a class="tree_f_svin_last" id="strom:r_1_194:a" name="strom:r_1_194:a" onclick="return tree_folderClick('strom','r_1_194');">
#       <span style="display: none">
#        +
#       </span>
#      </a>
#      <a class="treeitem_regal" id="strom:r_1_194:icon" onclick="return tree_select('strom','r_1_194');" ondblclick="tree_expand('strom','r_1_194');">
#       1940 - 1949
#      </a>
#     </div>
#     <div class="tree_items" id="strom:r_1_194:items" style="display:none">
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    var ja=new TWidget.okno.TProxy(TWidget.proxies,'strom','TTreeView');
# 	ja.css_prefix = '';
# 	TWidget.cache.init('strom');
# 	ja.slaves=new Object();
# 	ja.members=new Object();
# 	ja.linked=new Object();
# 	ja.handlers.select= TWidget.okno.tree_select;
# 	ja.handlers.select_child= TWidget.okno.tree_select_child;
# 	ja.handlers.update= TWidget.okno.widget_masterUpdate;
# 	ja.handlers.getSelectedText= TWidget.okno.tree_getSelectedText;
# 	ja.handlers.cache= TWidget.okno.widget_cache;
# 	ja.handlers.restore= TWidget.okno.widget_restore;
# 	ja.store.key=undefined;
#   </script>
#   //splitter
#   <div class="TSplitterVertical" id="splitter" onmousedown="return widget_splitter_down(this,event); " style="left: 226px;">
#   </div>
#   <script type="text/javascript">
#    var ja=new TWidget.okno.TProxy(TWidget.proxies,'splitter','TSplitter');
# 	ja.css_prefix = '';
# 	 ja.vertical=true;
# widget_splitter_init(ja);	 ja.levy['strom']='strom';
# 	 ja.pravy['panel']='panel';
# 	 ja.left_min=30;
# 	 ja.right_min=30;
# 	ja.handlers.restore= TWidget.okno.widget_splitter_restore;
#   </script>
#   //panel
#   <div class="TKnihyPanel" id="panel" style="left: 229px; width: auto;">
#    //panel_listknih
#    <div class="TListView" id="panel_listknih">
#     <div>
#      <a name="panel_listknih_head">
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <a>
#      </a>
#      <table border="" class="listview_table">
#       <colgroup>
#        <col class="listview_column_nazev" id="panel_listknih_column_nazev"/>
#       </colgroup>
#       <thead>
#        <tr>
#         <th class="listview_header_nazev" id="panel_listknih_headernazev">
#          Ročník
#         </th>
#        </tr>
#       </thead>
#       <tbody id="panel_listknih:tbody">
#        <tr onclick="widget_select('panel_listknih','2_9'); return false;">
#         <td>
#          1900
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_21'); return false;">
#         <td>
#          1901
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_33'); return false;">
#         <td>
#          1902
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_43'); return false;">
#         <td>
#          1903
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_58'); return false;">
#         <td>
#          1880
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_71'); return false;">
#         <td>
#          1881
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_82'); return false;">
#         <td>
#          1904
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_93'); return false;">
#         <td>
#          1882
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_106'); return false;">
#         <td>
#          1906
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_107'); return false;">
#         <td>
#          1907
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_108'); return false;">
#         <td>
#          1908
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_150'); return false;">
#         <td>
#          1883
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_151'); return false;">
#         <td>
#          1884
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_152'); return false;">
#         <td>
#          1885
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_153'); return false;">
#         <td>
#          1886
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_154'); return false;">
#         <td>
#          1887
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_155'); return false;">
#         <td>
#          1888
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_156'); return false;">
#         <td>
#          1889
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_157'); return false;">
#         <td>
#          1890
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_158'); return false;">
#         <td>
#          1891
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_159'); return false;">
#         <td>
#          1892
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_160'); return false;">
#         <td>
#          1893
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_162'); return false;">
#         <td>
#          1894
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_163'); return false;">
#         <td>
#          1895
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_164'); return false;">
#         <td>
#          1896
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_165'); return false;">
#         <td>
#          1897
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_166'); return false;">
#         <td>
#          1898
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_167'); return false;">
#         <td>
#          1899
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_199'); return false;">
#         <td>
#          1909
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_210'); return false;">
#         <td>
#          1910
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_221'); return false;">
#         <td>
#          1911
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_269'); return false;">
#         <td>
#          1912
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_270'); return false;">
#         <td>
#          1913
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_285'); return false;">
#         <td>
#          1914
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_286'); return false;">
#         <td>
#          1915
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_287'); return false;">
#         <td>
#          1916
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_288'); return false;">
#         <td>
#          1917
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_339'); return false;">
#         <td>
#          1870
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_341'); return false;">
#         <td>
#          1871
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_342'); return false;">
#         <td>
#          1872
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_343'); return false;">
#         <td>
#          1873
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_344'); return false;">
#         <td>
#          1874
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_345'); return false;">
#         <td>
#          1875
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_346'); return false;">
#         <td>
#          1876
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_347'); return false;">
#         <td>
#          1877
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_348'); return false;">
#         <td>
#          1878
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_349'); return false;">
#         <td>
#          1879
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_459'); return false;">
#         <td>
#          1918
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_470'); return false;">
#         <td>
#          1919
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_481'); return false;">
#         <td>
#          1920
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_482'); return false;">
#         <td>
#          1921
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_503'); return false;">
#         <td>
#          1922
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_515'); return false;">
#         <td>
#          1828
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_519'); return false;">
#         <td>
#          1829
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_522'); return false;">
#         <td>
#          1830
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_525'); return false;">
#         <td>
#          1831
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_528'); return false;">
#         <td>
#          1832
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_531'); return false;">
#         <td>
#          1833
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_536'); return false;">
#         <td>
#          1834
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_539'); return false;">
#         <td>
#          1835
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_544'); return false;">
#         <td>
#          1836
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_549'); return false;">
#         <td>
#          1837
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_554'); return false;">
#         <td>
#          1838
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_560'); return false;">
#         <td>
#          1839
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_565'); return false;">
#         <td>
#          1840
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_570'); return false;">
#         <td>
#          1923
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_581'); return false;">
#         <td>
#          1924
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_601'); return false;">
#         <td>
#          1925
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_613'); return false;">
#         <td>
#          1841
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_618'); return false;">
#         <td>
#          1842
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_623'); return false;">
#         <td>
#          1843
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_628'); return false;">
#         <td>
#          1844
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_633'); return false;">
#         <td>
#          1845
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_638'); return false;">
#         <td>
#          1846
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_643'); return false;">
#         <td>
#          1847
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_648'); return false;">
#         <td>
#          1848
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_653'); return false;">
#         <td>
#          1849
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_658'); return false;">
#         <td>
#          1850
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_663'); return false;">
#         <td>
#          1851
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_668'); return false;">
#         <td>
#          1852
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_674'); return false;">
#         <td>
#          1860
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_683'); return false;">
#         <td>
#          1926
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_719'); return false;">
#         <td>
#          1861
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_720'); return false;">
#         <td>
#          1862
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_721'); return false;">
#         <td>
#          1863
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_722'); return false;">
#         <td>
#          1864
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_723'); return false;">
#         <td>
#          1865
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_724'); return false;">
#         <td>
#          1866
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_725'); return false;">
#         <td>
#          1867
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_727'); return false;">
#         <td>
#          1868
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_728'); return false;">
#         <td>
#          1869
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_769'); return false;">
#         <td>
#          1853
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_771'); return false;">
#         <td>
#          1854
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_773'); return false;">
#         <td>
#          1855
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_775'); return false;">
#         <td>
#          1856
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_777'); return false;">
#         <td>
#          1857
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_779'); return false;">
#         <td>
#          1858
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_781'); return false;">
#         <td>
#          1859
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_915'); return false;">
#         <td>
#          1927
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_926'); return false;">
#         <td>
#          1928
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_937'); return false;">
#         <td>
#          1929
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_948'); return false;">
#         <td>
#          1930
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_959'); return false;">
#         <td>
#          1931
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_970'); return false;">
#         <td>
#          1932
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_981'); return false;">
#         <td>
#          1933
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_992'); return false;">
#         <td>
#          1934
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1003'); return false;">
#         <td>
#          1935
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1014'); return false;">
#         <td>
#          1936
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1025'); return false;">
#         <td>
#          1937
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1036'); return false;">
#         <td>
#          1938
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1058'); return false;">
#         <td>
#          1940
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1069'); return false;">
#         <td>
#          1941
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1080'); return false;">
#         <td>
#          1942
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1091'); return false;">
#         <td>
#          1943
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1102'); return false;">
#         <td>
#          1944
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1113'); return false;">
#         <td>
#          1945
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1124'); return false;">
#         <td>
#          1946
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1135'); return false;">
#         <td>
#          1947
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1146'); return false;">
#         <td>
#          1948
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1164'); return false;">
#         <td>
#          1905
#         </td>
#        </tr>
#       </tbody>
#      </table>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    var ja=new TWidget.okno.TProxy(TWidget.proxies,'panel','TKnihyPanel');
# 	ja.css_prefix = '';
# 	ja.setMaster(TWidget.proxies.get('strom'));
# 	TWidget.proxies.get('strom').addSlaveProxy(ja);
# 	TWidget.cache.init('panel');
# 	ja.slaves=new Object();
# 	ja.members=new Object();
# 	ja.handlers.select= TWidget.okno.widget_select;
# 	ja.handlers.update= TWidget.okno.widget_panelUpdate;
# 	ja.handlers.translateKey= TWidget.okno.knihyPanel_translateKey;
# 	ja.handlers.cache= TWidget.okno.widget_cache;
# 	ja.handlers.restore= TWidget.okno.widget_restore;
# 	ja.store.masterKey = '';
# 	ja.store.key="";
# var ja=TWidget.proxies.get('panel');
#  TWidget.cache.cache(ja,ja.callAction('translateKey',''));
#   </script>
#  </body>
# </html>
# <head>
#  <meta content="text/Html; charset=utf-8" http-equiv="Content-Type"/>
#  <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-7FB5E9QP3D&amp;cx=c&amp;_slc=1" type="text/javascript">
#  </script>
#  <script async="" src="//www.google-analytics.com/analytics.js">
#  </script>
#  <script src="/lib/widget/script/widget.js.php" type="text/javascript">
#  </script>
#  <script src="/lib/widget/script/tree.js" type="text/javascript">
#  </script>
#  <script src="/lib/widget/script/splitter.js" type="text/javascript">
#  </script>
#  <script src="/lib/script/dom.js" type="text/javascript">
#  </script>
#  <script src="/lib/widget/script/list.js" type="text/javascript">
#  </script>
#  <script src="/lib/widget/script/sliderbar.js" type="text/javascript">
#  </script>
#  <script src="/knihovny/ckd/knihovna/script/knihovna.js" type="text/javascript">
#  </script>
#  <link href="/lib/widget/style/tree.css.php" rel="stylesheet" type="text/css"/>
#  <link href="/lib/widget/style/splitter.css.php" rel="stylesheet" type="text/css"/>
#  <link href="/lib/widget/style/list.css.php" rel="stylesheet" type="text/css"/>
#  <link href="/lib/widget/style/sliderbar.css.php" rel="stylesheet" type="text/css"/>
#  <script type="text/javascript">
#   TWidget.sid = '12002750';
#  </script>
#  <link href="style/knihovna.css" rel="stylesheet" type="text/css"/>
#  <link href="style/index.css" rel="stylesheet" type="text/css"/>
#  <link href="style/menu.css" rel="stylesheet" type="text/css"/>
#  <title>
#   Knihovna
#  </title>
# </head>
# <body id="index">
#  <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-49883798-5', 'depositum.cz');
#   ga('send', 'pageview');
#  </script>
#  <div id="menu">
#   <div id="menu_leve">
#    <a class="menuitem_selected" href="index.php?dle=rocnik">
#     Ročníky
#    </a>
#    <a class="menuitem" href="index.php?dle=autor">
#     Autoři
#    </a>
#    <a class="menuitem" href="index.php?dle=keyword">
#     Klíčová slova
#    </a>
#   </div>
#   <div id="menu_prave">
#    <form action="find.php" method="post">
#     <a class="menuitem" href="help/simple.html">
#      Nápověda
#     </a>
#     <a class="menuitem" href="index.php?knihovna:viewmode=0">
#      Jednoduché
#     </a>
#     <input class="text" name="nazev" type="Text"/>
#     <input name="simple" type="hidden"/>
#     <input class="button" type="submit" value="Vyhledej"/>
#    </form>
#   </div>
#   <div id="menu_center">
#    <div id="widget_actionActive" style="display: none;">
#    </div>
#    <div id="widget_actionDone" style="display: block;">
#     <a href="/">
#      digiknihovna DEPOSITUM
#     </a>
#    </div>
#   </div>
#  </div>
#  //strom
#  <div class="TTreeView" id="strom" style="width: 223px;">
#   <div class="tree_item" id="strom:1_1">
#    <span style="display:none">
#     `
#    </span>
#    <a class="tree_f_rozvin_last" id="strom:1_1:a" name="strom:1_1:a" onclick="return tree_folderClick('strom','1_1')">
#     <span style="display: none">
#      *
#     </span>
#    </a>
#    <a class="treeitem_casopis_selected" id="strom:1_1:icon" onclick="return tree_select('strom','1_1');" ondblclick="return tree_expand('strom','1_1')">
#     ČKD
#    </a>
#   </div>
#   <div class="tree_items" id="strom:1_1:items" style="">
#    <div class="tree_item" id="strom:r_1_182">
#     <span style="display:none">
#      |
#     </span>
#     <span class="tree_vetev_ne">
#     </span>
#     <a class="tree_f_svin" id="strom:r_1_182:a" name="strom:r_1_182:a" onclick="return tree_folderClick('strom','r_1_182');">
#      <span style="display: none">
#       +
#      </span>
#     </a>
#     <a class="treeitem_regal" id="strom:r_1_182:icon" onclick="return tree_select('strom','r_1_182');" ondblclick="tree_expand('strom','r_1_182');">
#      1820 - 1829
#     </a>
#    </div>
#    <div class="tree_items" id="strom:r_1_182:items" style="display:none">
#    </div>
#    <div class="tree_item" id="strom:r_1_183">
#     <span style="display:none">
#      |
#     </span>
#     <span class="tree_vetev_ne">
#     </span>
#     <a class="tree_f_svin" id="strom:r_1_183:a" name="strom:r_1_183:a" onclick="return tree_folderClick('strom','r_1_183');">
#      <span style="display: none">
#       +
#      </span>
#     </a>
#     <a class="treeitem_regal" id="strom:r_1_183:icon" onclick="return tree_select('strom','r_1_183');" ondblclick="tree_expand('strom','r_1_183');">
#      1830 - 1839
#     </a>
#    </div>
#    <div class="tree_items" id="strom:r_1_183:items" style="display:none">
#    </div>
#    <div class="tree_item" id="strom:r_1_184">
#     <span style="display:none">
#      |
#     </span>
#     <span class="tree_vetev_ne">
#     </span>
#     <a class="tree_f_svin" id="strom:r_1_184:a" name="strom:r_1_184:a" onclick="return tree_folderClick('strom','r_1_184');">
#      <span style="display: none">
#       +
#      </span>
#     </a>
#     <a class="treeitem_regal" id="strom:r_1_184:icon" onclick="return tree_select('strom','r_1_184');" ondblclick="tree_expand('strom','r_1_184');">
#      1840 - 1849
#     </a>
#    </div>
#    <div class="tree_items" id="strom:r_1_184:items" style="display:none">
#    </div>
#    <div class="tree_item" id="strom:r_1_185">
#     <span style="display:none">
#      |
#     </span>
#     <span class="tree_vetev_ne">
#     </span>
#     <a class="tree_f_svin" id="strom:r_1_185:a" name="strom:r_1_185:a" onclick="return tree_folderClick('strom','r_1_185');">
#      <span style="display: none">
#       +
#      </span>
#     </a>
#     <a class="treeitem_regal" id="strom:r_1_185:icon" onclick="return tree_select('strom','r_1_185');" ondblclick="tree_expand('strom','r_1_185');">
#      1850 - 1859
#     </a>
#    </div>
#    <div class="tree_items" id="strom:r_1_185:items" style="display:none">
#    </div>
#    <div class="tree_item" id="strom:r_1_186">
#     <span style="display:none">
#      |
#     </span>
#     <span class="tree_vetev_ne">
#     </span>
#     <a class="tree_f_svin" id="strom:r_1_186:a" name="strom:r_1_186:a" onclick="return tree_folderClick('strom','r_1_186');">
#      <span style="display: none">
#       +
#      </span>
#     </a>
#     <a class="treeitem_regal" id="strom:r_1_186:icon" onclick="return tree_select('strom','r_1_186');" ondblclick="tree_expand('strom','r_1_186');">
#      1860 - 1869
#     </a>
#    </div>
#    <div class="tree_items" id="strom:r_1_186:items" style="display:none">
#    </div>
#    <div class="tree_item" id="strom:r_1_187">
#     <span style="display:none">
#      |
#     </span>
#     <span class="tree_vetev_ne">
#     </span>
#     <a class="tree_f_svin" id="strom:r_1_187:a" name="strom:r_1_187:a" onclick="return tree_folderClick('strom','r_1_187');">
#      <span style="display: none">
#       +
#      </span>
#     </a>
#     <a class="treeitem_regal" id="strom:r_1_187:icon" onclick="return tree_select('strom','r_1_187');" ondblclick="tree_expand('strom','r_1_187');">
#      1870 - 1879
#     </a>
#    </div>
#    <div class="tree_items" id="strom:r_1_187:items" style="display:none">
#    </div>
#    <div class="tree_item" id="strom:r_1_188">
#     <span style="display:none">
#      |
#     </span>
#     <span class="tree_vetev_ne">
#     </span>
#     <a class="tree_f_svin" id="strom:r_1_188:a" name="strom:r_1_188:a" onclick="return tree_folderClick('strom','r_1_188');">
#      <span style="display: none">
#       +
#      </span>
#     </a>
#     <a class="treeitem_regal" id="strom:r_1_188:icon" onclick="return tree_select('strom','r_1_188');" ondblclick="tree_expand('strom','r_1_188');">
#      1880 - 1889
#     </a>
#    </div>
#    <div class="tree_items" id="strom:r_1_188:items" style="display:none">
#    </div>
#    <div class="tree_item" id="strom:r_1_189">
#     <span style="display:none">
#      |
#     </span>
#     <span class="tree_vetev_ne">
#     </span>
#     <a class="tree_f_svin" id="strom:r_1_189:a" name="strom:r_1_189:a" onclick="return tree_folderClick('strom','r_1_189');">
#      <span style="display: none">
#       +
#      </span>
#     </a>
#     <a class="treeitem_regal" id="strom:r_1_189:icon" onclick="return tree_select('strom','r_1_189');" ondblclick="tree_expand('strom','r_1_189');">
#      1890 - 1899
#     </a>
#    </div>
#    <div class="tree_items" id="strom:r_1_189:items" style="display:none">
#    </div>
#    <div class="tree_item" id="strom:r_1_190">
#     <span style="display:none">
#      |
#     </span>
#     <span class="tree_vetev_ne">
#     </span>
#     <a class="tree_f_svin" id="strom:r_1_190:a" name="strom:r_1_190:a" onclick="return tree_folderClick('strom','r_1_190');">
#      <span style="display: none">
#       +
#      </span>
#     </a>
#     <a class="treeitem_regal" id="strom:r_1_190:icon" onclick="return tree_select('strom','r_1_190');" ondblclick="tree_expand('strom','r_1_190');">
#      1900 - 1909
#     </a>
#    </div>
#    <div class="tree_items" id="strom:r_1_190:items" style="display:none">
#    </div>
#    <div class="tree_item" id="strom:r_1_191">
#     <span style="display:none">
#      |
#     </span>
#     <span class="tree_vetev_ne">
#     </span>
#     <a class="tree_f_svin" id="strom:r_1_191:a" name="strom:r_1_191:a" onclick="return tree_folderClick('strom','r_1_191');">
#      <span style="display: none">
#       +
#      </span>
#     </a>
#     <a class="treeitem_regal" id="strom:r_1_191:icon" onclick="return tree_select('strom','r_1_191');" ondblclick="tree_expand('strom','r_1_191');">
#      1910 - 1919
#     </a>
#    </div>
#    <div class="tree_items" id="strom:r_1_191:items" style="display:none">
#    </div>
#    <div class="tree_item" id="strom:r_1_192">
#     <span style="display:none">
#      |
#     </span>
#     <span class="tree_vetev_ne">
#     </span>
#     <a class="tree_f_svin" id="strom:r_1_192:a" name="strom:r_1_192:a" onclick="return tree_folderClick('strom','r_1_192');">
#      <span style="display: none">
#       +
#      </span>
#     </a>
#     <a class="treeitem_regal" id="strom:r_1_192:icon" onclick="return tree_select('strom','r_1_192');" ondblclick="tree_expand('strom','r_1_192');">
#      1920 - 1929
#     </a>
#    </div>
#    <div class="tree_items" id="strom:r_1_192:items" style="display:none">
#    </div>
#    <div class="tree_item" id="strom:r_1_193">
#     <span style="display:none">
#      |
#     </span>
#     <span class="tree_vetev_ne">
#     </span>
#     <a class="tree_f_svin" id="strom:r_1_193:a" name="strom:r_1_193:a" onclick="return tree_folderClick('strom','r_1_193');">
#      <span style="display: none">
#       +
#      </span>
#     </a>
#     <a class="treeitem_regal" id="strom:r_1_193:icon" onclick="return tree_select('strom','r_1_193');" ondblclick="tree_expand('strom','r_1_193');">
#      1930 - 1939
#     </a>
#    </div>
#    <div class="tree_items" id="strom:r_1_193:items" style="display:none">
#    </div>
#    <div class="tree_item" id="strom:r_1_194">
#     <span style="display:none">
#      `
#     </span>
#     <span class="tree_vetev_ne">
#     </span>
#     <a class="tree_f_svin_last" id="strom:r_1_194:a" name="strom:r_1_194:a" onclick="return tree_folderClick('strom','r_1_194');">
#      <span style="display: none">
#       +
#      </span>
#     </a>
#     <a class="treeitem_regal" id="strom:r_1_194:icon" onclick="return tree_select('strom','r_1_194');" ondblclick="tree_expand('strom','r_1_194');">
#      1940 - 1949
#     </a>
#    </div>
#    <div class="tree_items" id="strom:r_1_194:items" style="display:none">
#    </div>
#   </div>
#  </div>
#  <script type="text/javascript">
#   var ja=new TWidget.okno.TProxy(TWidget.proxies,'strom','TTreeView');
# 	ja.css_prefix = '';
# 	TWidget.cache.init('strom');
# 	ja.slaves=new Object();
# 	ja.members=new Object();
# 	ja.linked=new Object();
# 	ja.handlers.select= TWidget.okno.tree_select;
# 	ja.handlers.select_child= TWidget.okno.tree_select_child;
# 	ja.handlers.update= TWidget.okno.widget_masterUpdate;
# 	ja.handlers.getSelectedText= TWidget.okno.tree_getSelectedText;
# 	ja.handlers.cache= TWidget.okno.widget_cache;
# 	ja.handlers.restore= TWidget.okno.widget_restore;
# 	ja.store.key=undefined;
#  </script>
#  //splitter
#  <div class="TSplitterVertical" id="splitter" onmousedown="return widget_splitter_down(this,event); " style="left: 226px;">
#  </div>
#  <script type="text/javascript">
#   var ja=new TWidget.okno.TProxy(TWidget.proxies,'splitter','TSplitter');
# 	ja.css_prefix = '';
# 	 ja.vertical=true;
# widget_splitter_init(ja);	 ja.levy['strom']='strom';
# 	 ja.pravy['panel']='panel';
# 	 ja.left_min=30;
# 	 ja.right_min=30;
# 	ja.handlers.restore= TWidget.okno.widget_splitter_restore;
#  </script>
#  //panel
#  <div class="TKnihyPanel" id="panel" style="left: 229px; width: auto;">
#   //panel_listknih
#   <div class="TListView" id="panel_listknih">
#    <div>
#     <a name="panel_listknih_head">
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <a>
#     </a>
#     <table border="" class="listview_table">
#      <colgroup>
#       <col class="listview_column_nazev" id="panel_listknih_column_nazev"/>
#      </colgroup>
#      <thead>
#       <tr>
#        <th class="listview_header_nazev" id="panel_listknih_headernazev">
#         Ročník
#        </th>
#       </tr>
#      </thead>
#      <tbody id="panel_listknih:tbody">
#       <tr onclick="widget_select('panel_listknih','2_9'); return false;">
#        <td>
#         1900
#        </td>
#       </tr>
#       <tr onclick="widget_select('panel_listknih','2_21'); return false;">
#        <td>
#         1901
#        </td>
#       </tr>
#       <tr onclick="widget_select('panel_listknih','2_33'); return false;">
#        <td>
#         1902
#        </td>
#       </tr>
#       <tr onclick="widget_select('panel_listknih','2_43'); return false;">
#        <td>
#         1903
#        </td>
#       </tr>
#       <tr onclick="widget_select('panel_listknih','2_58'); return false;">
#        <td>
#         1880
#        </td>
#       </tr>
#       <tr onclick="widget_select('panel_listknih','2_71'); return false;">
#        <td>
#         1881
#        </td>
#       </tr>
#       <tr onclick="widget_select('panel_listknih','2_82'); return false;">
#        <td>
#         1904
#        </td>
#       </tr>
#       <tr onclick="widget_select('panel_listknih','2_93'); return false;">
#        <td>
#         1882
#        </td>
#       </tr>
# ...
#         <td>
#          1880
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_71'); return false;">
#         <td>
#          1881
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_82'); return false;">
#         <td>
#          1904
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_93'); return false;">
#         <td>
#          1882
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_106'); return false;">
#         <td>
#          1906
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_107'); return false;">
#         <td>
#          1907
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_108'); return false;">
#         <td>
#          1908
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_150'); return false;">
#         <td>
#          1883
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_151'); return false;">
#         <td>
#          1884
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_152'); return false;">
#         <td>
#          1885
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_153'); return false;">
#         <td>
#          1886
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_154'); return false;">
#         <td>
#          1887
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_155'); return false;">
#         <td>
#          1888
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_156'); return false;">
#         <td>
#          1889
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_157'); return false;">
#         <td>
#          1890
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_158'); return false;">
#         <td>
#          1891
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_159'); return false;">
#         <td>
#          1892
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_160'); return false;">
#         <td>
#          1893
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_162'); return false;">
#         <td>
#          1894
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_163'); return false;">
#         <td>
#          1895
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_164'); return false;">
#         <td>
#          1896
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_165'); return false;">
#         <td>
#          1897
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_166'); return false;">
#         <td>
#          1898
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_167'); return false;">
#         <td>
#          1899
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_199'); return false;">
#         <td>
#          1909
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_210'); return false;">
#         <td>
#          1910
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_221'); return false;">
#         <td>
#          1911
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_269'); return false;">
#         <td>
#          1912
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_270'); return false;">
#         <td>
#          1913
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_285'); return false;">
#         <td>
#          1914
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_286'); return false;">
#         <td>
#          1915
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_287'); return false;">
#         <td>
#          1916
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_288'); return false;">
#         <td>
#          1917
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_339'); return false;">
#         <td>
#          1870
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_341'); return false;">
#         <td>
#          1871
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_342'); return false;">
#         <td>
#          1872
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_343'); return false;">
#         <td>
#          1873
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_344'); return false;">
#         <td>
#          1874
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_345'); return false;">
#         <td>
#          1875
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_346'); return false;">
#         <td>
#          1876
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_347'); return false;">
#         <td>
#          1877
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_348'); return false;">
#         <td>
#          1878
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_349'); return false;">
#         <td>
#          1879
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_459'); return false;">
#         <td>
#          1918
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_470'); return false;">
#         <td>
#          1919
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_481'); return false;">
#         <td>
#          1920
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_482'); return false;">
#         <td>
#          1921
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_503'); return false;">
#         <td>
#          1922
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_515'); return false;">
#         <td>
#          1828
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_519'); return false;">
#         <td>
#          1829
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_522'); return false;">
#         <td>
#          1830
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_525'); return false;">
#         <td>
#          1831
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_528'); return false;">
#         <td>
#          1832
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_531'); return false;">
#         <td>
#          1833
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_536'); return false;">
#         <td>
#          1834
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_539'); return false;">
#         <td>
#          1835
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_544'); return false;">
#         <td>
#          1836
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_549'); return false;">
#         <td>
#          1837
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_554'); return false;">
#         <td>
#          1838
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_560'); return false;">
#         <td>
#          1839
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_565'); return false;">
#         <td>
#          1840
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_570'); return false;">
#         <td>
#          1923
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_581'); return false;">
#         <td>
#          1924
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_601'); return false;">
#         <td>
#          1925
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_613'); return false;">
#         <td>
#          1841
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_618'); return false;">
#         <td>
#          1842
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_623'); return false;">
#         <td>
#          1843
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_628'); return false;">
#         <td>
#          1844
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_633'); return false;">
#         <td>
#          1845
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_638'); return false;">
#         <td>
#          1846
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_643'); return false;">
#         <td>
#          1847
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_648'); return false;">
#         <td>
#          1848
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_653'); return false;">
#         <td>
#          1849
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_658'); return false;">
#         <td>
#          1850
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_663'); return false;">
#         <td>
#          1851
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_668'); return false;">
#         <td>
#          1852
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_674'); return false;">
#         <td>
#          1860
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_683'); return false;">
#         <td>
#          1926
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_719'); return false;">
#         <td>
#          1861
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_720'); return false;">
#         <td>
#          1862
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_721'); return false;">
#         <td>
#          1863
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_722'); return false;">
#         <td>
#          1864
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_723'); return false;">
#         <td>
#          1865
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_724'); return false;">
#         <td>
#          1866
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_725'); return false;">
#         <td>
#          1867
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_727'); return false;">
#         <td>
#          1868
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_728'); return false;">
#         <td>
#          1869
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_769'); return false;">
#         <td>
#          1853
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_771'); return false;">
#         <td>
#          1854
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_773'); return false;">
#         <td>
#          1855
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_775'); return false;">
#         <td>
#          1856
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_777'); return false;">
#         <td>
#          1857
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_779'); return false;">
#         <td>
#          1858
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_781'); return false;">
#         <td>
#          1859
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_915'); return false;">
#         <td>
#          1927
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_926'); return false;">
#         <td>
#          1928
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_937'); return false;">
#         <td>
#          1929
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_948'); return false;">
#         <td>
#          1930
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_959'); return false;">
#         <td>
#          1931
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_970'); return false;">
#         <td>
#          1932
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_981'); return false;">
#         <td>
#          1933
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_992'); return false;">
#         <td>
#          1934
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1003'); return false;">
#         <td>
#          1935
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1014'); return false;">
#         <td>
#          1936
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1025'); return false;">
#         <td>
#          1937
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1036'); return false;">
#         <td>
#          1938
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1058'); return false;">
#         <td>
#          1940
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1069'); return false;">
#         <td>
#          1941
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1080'); return false;">
#         <td>
#          1942
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1091'); return false;">
#         <td>
#          1943
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1102'); return false;">
#         <td>
#          1944
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1113'); return false;">
#         <td>
#          1945
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1124'); return false;">
#         <td>
#          1946
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1135'); return false;">
#         <td>
#          1947
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1146'); return false;">
#         <td>
#          1948
#         </td>
#        </tr>
#        <tr onclick="widget_select('panel_listknih','2_1164'); return false;">
#         <td>
#          1905
#         </td>
#        </tr>
#       </tbody>
#      </table>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    var ja=new TWidget.okno.TProxy(TWidget.proxies,'panel','TKnihyPanel');
# 	ja.css_prefix = '';
# 	ja.setMaster(TWidget.proxies.get('strom'));
# 	TWidget.proxies.get('strom').addSlaveProxy(ja);
# 	TWidget.cache.init('panel');
# 	ja.slaves=new Object();
# 	ja.members=new Object();
# 	ja.handlers.select= TWidget.okno.widget_select;
# 	ja.handlers.update= TWidget.okno.widget_panelUpdate;
# 	ja.handlers.translateKey= TWidget.okno.knihyPanel_translateKey;
# 	ja.handlers.cache= TWidget.okno.widget_cache;
# 	ja.handlers.restore= TWidget.okno.widget_restore;
# 	ja.store.masterKey = '';
# 	ja.store.key="";
# var ja=TWidget.proxies.get('panel');
#  TWidget.cache.cache(ja,ja.callAction('translateKey',''));
#   </script>
#  </body>
# </html>

# %%
# %%sql

# %%
print(BeautifulSoup(requests.get("http://depositum.cz/knihovny/ckd/index.php?txgame:typ=r&txgame:id=1_189&dle=").text).prettify())
# Out:
# <!DOCTYPE Html PUBLIC "-//W3C//DTD Html 4.01//EN"
#         "http://www.w3.org/TR/Html4/strict.dtd">
# <html>
#  <meta content="text/Html; charset=utf-8" http-equiv="Content-Type"/>
#  <head>
#   <script src="/lib/widget/script/widget.js.php" type="text/javascript">
#   </script>
#   <link href="/knihovny/ckd/style/textgame.css" rel="stylesheet" type="text/css"/>
#   <link href="style/knihovna.css" rel="stylesheet" type="text/css"/>
#   <link href="style/index.css" rel="stylesheet" type="text/css"/>
#   <link href="style/menu.css" rel="stylesheet" type="text/css"/>
#   <title>
#    Knihovna
#   </title>
#  </head>
#  <body id="index">
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-49883798-5', 'depositum.cz');
#   ga('send', 'pageview');
#   </script>
#   <div class="txgame_page">
#    <div class="txgame_top">
#     <img id="gametop_img" src="img/depositum.gif"/>
#    </div>
#    <div class="txgame_side">
#     <h4 class="txgame_caption">
#      Prohlíej dle...
#     </h4>
#     <ul class="txgame_def">
#      <li class="txgame_def">
#       <a class="gamemenu_selected" href="index.php?dle=">
#        Dle titulù
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gamemenu" href="index.php?dle=autor">
#        Dle autorù
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gamemenu" href="index.php?dle=keyword">
#        Dle klíèových slov
#       </a>
#      </li>
#     </ul>
#     <h4 class="txgame_caption">
#      Jdi na...
#     </h4>
#     <ul class="txgame_def">
#      <li class="txgame_def">
#       <a class="gamemenu" href="../..">
#        Hlavní stranu
#        <emph>
#         Deposita
#        </emph>
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gamemenu" href="help/simple.html">
#        Nápovìdu
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gamemenu" href="?knihovna:viewmode=1">
#        Rozíøené ovládací rozhraní
#       </a>
#      </li>
#     </ul>
#     <h4 class="txgame_caption">
#      Vyhledávání
#     </h4>
#     <ul class="txgame_def">
#      <li class="txgame_def">
#       <a class="gamemenu" href="index.php?dle=find">
#        Pokroèilé vyhledávání
#       </a>
#      </li>
#      <form action="?dle=find" method="post">
#       <input id="" name="nazev" type="text"/>
#       <input name="dle" type="hidden" value="find"/>
#       <input type="submit" value="Vyhledej!"/>
#      </form>
#     </ul>
#     <h4 class="txgame_caption">
#      Vra se na...
#     </h4>
#     <ul class="txgame_def">
#      <li class="txgame_def">
#       <a class="gameitem_" href="?&amp;dle=">
#        Èasopisy z této sekce
#        <emph>
#         Deposita
#        </emph>
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gameitem_casopis" href="/knihovny/ckd/index.php?txgame:typ=1&amp;txgame:id=1&amp;dle=">
#        Èasopis ČKD
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="txgame_body">
#     <h2 class="txgame_heading">
#      Prohlííte roèníky
#      <span class="txgame_emph">
#       1890 - 1899
#      </span>
#     </h2>
#     <h4 class="txgame_caption">
#      Zvol roèník...
#     </h4>
#     <ul class="txgame_def">
#      <li class="txgame_def">
#       <a class="gameitem_rocnik" href="/knihovny/ckd/index.php?txgame:typ=2&amp;txgame:id=157&amp;dle=">
#        1890
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gameitem_rocnik" href="/knihovny/ckd/index.php?txgame:typ=2&amp;txgame:id=158&amp;dle=">
#        1891
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gameitem_rocnik" href="/knihovny/ckd/index.php?txgame:typ=2&amp;txgame:id=159&amp;dle=">
#        1892
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gameitem_rocnik" href="/knihovny/ckd/index.php?txgame:typ=2&amp;txgame:id=160&amp;dle=">
#        1893
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gameitem_rocnik" href="/knihovny/ckd/index.php?txgame:typ=2&amp;txgame:id=162&amp;dle=">
#        1894
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gameitem_rocnik" href="/knihovny/ckd/index.php?txgame:typ=2&amp;txgame:id=163&amp;dle=">
#        1895
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gameitem_rocnik" href="/knihovny/ckd/index.php?txgame:typ=2&amp;txgame:id=164&amp;dle=">
#        1896
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gameitem_rocnik" href="/knihovny/ckd/index.php?txgame:typ=2&amp;txgame:id=165&amp;dle=">
#        1897
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gameitem_rocnik" href="/knihovny/ckd/index.php?txgame:typ=2&amp;txgame:id=166&amp;dle=">
#        1898
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gameitem_rocnik" href="/knihovny/ckd/index.php?txgame:typ=2&amp;txgame:id=167&amp;dle=">
#        1899
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#  </body>
# </html>

# %%
print(BeautifulSoup(requests.get("http://depositum.cz/knihovny/ckd/index.php?txgame:typ=2&amp;txgame:id=159&amp;dle=rocnik").text).prettify())
# Out:
# <!DOCTYPE Html PUBLIC "-//W3C//DTD Html 4.01//EN"
#         "http://www.w3.org/TR/Html4/strict.dtd">
# <html>
#  <meta content="text/Html; charset=utf-8" http-equiv="Content-Type"/>
#  <head>
#   <script src="/lib/widget/script/widget.js.php" type="text/javascript">
#   </script>
#   <link href="/knihovny/ckd/style/textgame.css" rel="stylesheet" type="text/css"/>
#   <link href="style/knihovna.css" rel="stylesheet" type="text/css"/>
#   <link href="style/index.css" rel="stylesheet" type="text/css"/>
#   <link href="style/menu.css" rel="stylesheet" type="text/css"/>
#   <title>
#    Knihovna
#   </title>
#  </head>
#  <body id="index">
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-49883798-5', 'depositum.cz');
#   ga('send', 'pageview');
#   </script>
#   <div class="txgame_page">
#    <div class="txgame_top">
#     <img id="gametop_img" src="img/depositum.gif"/>
#    </div>
#    <div class="txgame_side">
#     <h4 class="txgame_caption">
#      Prohlíej dle...
#     </h4>
#     <ul class="txgame_def">
#      <li class="txgame_def">
#       <a class="gamemenu" href="index.php?dle=">
#        Dle titulù
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gamemenu" href="index.php?dle=autor">
#        Dle autorù
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gamemenu" href="index.php?dle=keyword">
#        Dle klíèových slov
#       </a>
#      </li>
#     </ul>
#     <h4 class="txgame_caption">
#      Jdi na...
#     </h4>
#     <ul class="txgame_def">
#      <li class="txgame_def">
#       <a class="gamemenu" href="../..">
#        Hlavní stranu
#        <emph>
#         Deposita
#        </emph>
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gamemenu" href="help/simple.html">
#        Nápovìdu
#       </a>
#      </li>
#      <li class="txgame_def">
#       <a class="gamemenu" href="?knihovna:viewmode=1">
#        Rozíøené ovládací rozhraní
#       </a>
#      </li>
#     </ul>
#     <h4 class="txgame_caption">
#      Vyhledávání
#     </h4>
#     <ul class="txgame_def">
#      <li class="txgame_def">
#       <a class="gamemenu" href="index.php?dle=find">
#        Pokroèilé vyhledávání
#       </a>
#      </li>
#      <form action="?dle=find" method="post">
#       <input id="" name="nazev" type="text"/>
#       <input name="dle" type="hidden" value="find"/>
#       <input type="submit" value="Vyhledej!"/>
#      </form>
#     </ul>
#    </div>
#    <div class="txgame_body">
#     <h2 class="txgame_heading">
#      Prohlííte
#      <span class="txgame_emph">
#       èasopisy z této sekce
#       <emph>
#        Deposita
#       </emph>
#      </span>
#     </h2>
#     <h4 class="txgame_caption">
#      Zvol èasopis...
#     </h4>
#     <ul class="txgame_def">
#      <li class="txgame_def">
#       <a class="gameitem_casopis" href="/knihovny/ckd/index.php?txgame:typ=1&amp;txgame:id=1&amp;dle=rocnik">
#        ČKD
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# ## Experiment with Google Books

# %%
url = "https://books.google.cz/books?id=xaBbAAAAcAAJ&hl=cs&pg=PA1#v=onepage&q&f=false"

# %%
id = re.search('id=([^&]+)&', url).group(1)
id
# Out:
# 'xaBbAAAAcAAJ'

# %%
gb = PyGoogleBooks.GoogleBook(id) # "", w=1280)
print(gb.name)
print(gb.authors)
print(gb.description)
print(gb.url)
#print(gb.cover_link)
#print(gb.get_link_to_page(page_number=5))
#print(gb.get_pages(last_page_number=20, ignore_errors=True))
# Out:
# Casopis pro Katolicke Duchowenstwo
# ['Google Книги']
#
# https://books.google.ru/books?id=xaBbAAAAcAAJ

# %%
pages = gb.get_pages(last_page_number=20, ignore_errors=True)

# %%
response = requests.get(pages[13])
img = Image.open(io.BytesIO(response.content))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=575x987>

# %%
p = doc.load_page(20)
pix = p.get_pixmap()
np_array = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.height, pix.width, pix.n)
fig, ax = plt.subplots(dpi=300)
ax.imshow(np_array)
ax.set_axis_off()

# %%
# %%time
pytesseract.image_to_string(np_array, lang="ces")

# %% [markdown]
# Tuto proceduru nyní snadno aplikujeme na všechny stránky v daném dokumentu. Tato procedura však již může zabrat nezanedbatelný čas.

# %%
# %%time
text = ""
for p in doc:
    pix = p.get_pixmap()
    np_array = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.height, pix.width, pix.n)
    str = pytesseract.image_to_string(np_array, lang="ces") + "[pagebreak]"
    text += str

# %% [markdown]
# Podívejme se nyní na výsledný text. Z kolika sestává znaků?

# %%
len(text)

# %%
text[16000:17000]

# %% [markdown]
# Vidíme, že výsledky nejsou kdovíjaké.

# %% [markdown]
# ### Morfologické transformace
#
# Často se potýkáme s tím, že podkladové obrázky (skeny jednotlivých stran) nejsou v dobré kvalitě. Existuje však řada algoritmů "out-of-the-box", které mohou kvalitu obrázků změnit, např. zvýšením kontrastu.

# %%
p = doc.load_page(20)
pix = p.get_pixmap()
np_array = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.height, pix.width, pix.n)

# %%
kernel = np.ones((2, 2), np.uint8)
np_array_corrected = cv2.erode(np_array, kernel, iterations=1)
fig, ax = plt.subplots(dpi=300)
ax.imshow(np_array_corrected)
ax.set_axis_off()
print(pytesseract.image_to_string(np_array_corrected, lang="ces"))

# %%
# DILATION
kernel = np.ones((1, 1), np.uint8)
np_array_corrected = cv2.dilate(np_array, kernel, iterations=1)
fig, ax = plt.subplots(dpi=300)
ax.imshow(np_array_corrected)
ax.set_axis_off()
print(pytesseract.image_to_string(np_array_corrected, lang="ces"))

# %%
# EROSION
kernel = np.ones((1, 1), np.uint8)
np_array_corrected = cv2.erode(np_array, kernel, iterations=1)
fig, ax = plt.subplots(dpi=300)
ax.imshow(np_array_corrected)
ax.set_axis_off()
print(pytesseract.image_to_string(np_array_corrected, lang="ces"))

# %%
# CLOSING
kernel = np.ones((1, 1), np.uint8)
np_array_corrected = cv2.morphologyEx(np_array, cv2.MORPH_CLOSE, kernel)
fig, ax = plt.subplots(dpi=300)
ax.imshow(np_array_corrected)
ax.set_axis_off()
print(pytesseract.image_to_string(np_array_corrected, lang="ces"))

# %%
kernel = np.ones((1,1),np.uint8)
opening = cv2.morphologyEx(np_array, cv2.MORPH_OPEN, kernel)
np_array_corrected = cv2.morphologyEx(np_array, cv2.MORPH_CLOSE, kernel)
fig, ax = plt.subplots(dpi=300)
ax.imshow(np_array_corrected)
ax.set_axis_off()
print(pytesseract.image_to_string(np_array_corrected, lang="ces"))
